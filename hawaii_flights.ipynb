# %%
# Import Dependencies
import pandas as pd
import os
import csv

# %%
csvpath_2019 = "Possible Datasets/2019/2019_AGGREGATED.csv"
csvpath_2020 = "Possible Datasets/2020/Hawaii_flights_2020.csv"
csvpath_2021 = "Possible Datasets/2021/Hawaii_flights_2021.csv"

flights_2019 = pd.read_csv(csvpath_2019)
flights_2020 = pd.read_csv(csvpath_2020)
flights_2021 = pd.read_csv(csvpath_2021)

# %%
len(flights_2019)
# Out:
# 987615

# %%
flights_2019.head()
# Out:
#    YEAR  QUARTER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_STATE_ABR ORIGIN_STATE_NM  \
# 0  2019        1              10994    CHS               SC  South Carolina
# 1  2019        1              10994    CHS               SC  South Carolina
# 2  2019        1              10994    CHS               SC  South Carolina
# 3  2019        1              10994    CHS               SC  South Carolina
# 4  2019        1              10994    CHS               SC  South Carolina
#
#    DEST_AIRPORT_ID DEST DEST_STATE_ABR DEST_STATE_NM    AIRPORT_GROUP  \
# 0            13830  OGG             HI        Hawaii  CHS:EWR:SFO:OGG
# 1            12758  KOA             HI        Hawaii  CHS:IAD:LAX:KOA
# 2            12982  LIH             HI        Hawaii  CHS:IAD:LAX:LIH
# 3            12173  HNL             HI        Hawaii  CHS:IAD:SFO:HNL
# 4            12173  HNL             HI        Hawaii  CHS:IAH:SFO:HNL
#
#   TK_CARRIER_GROUP OP_CARRIER_GROUP TICKET_CARRIER OPERATING_CARRIER  \
# 0         UA:UA:UA         UA:UA:UA             UA                UA
# 1         UA:UA:UA         UA:UA:UA             UA                UA
# 2         UA:UA:UA         UA:UA:UA             UA                UA
# 3         UA:UA:UA         C5:UA:UA             UA                99
# 4         UA:UA:UA         UA:UA:UA             UA                UA
#
#    PASSENGERS  MARKET_FARE
# 0           1       355.00
# 1           1       444.00
# 2           1       467.00
# 3           1       515.00
# 4           1       525.12

# %%
flights_2019 = flights_2019[flights_2019["DEST_STATE_NM"]== "Hawaii"]

# %%
len(flights_2019)
# Out:
# 516835

# %%
flights_2019 = flights_2019[flights_2019["ORIGIN_STATE_NM"]!= "Hawaii"]
flights_2020 = flights_2020[flights_2020["ORIGIN_STATE_NM"]!= "Hawaii"]
flights_2021 = flights_2021[flights_2021["ORIGIN_STATE_NM"]!= "Hawaii"]

# %%
len(flights_2019)
#len(flights_2020)
#len(flights_2021)
# Out:
# 467347

# %%
hawaii_flights = pd.concat([flights_2019,flights_2020,flights_2021])

# %%
hawaii_flights
# Out:
#         YEAR  QUARTER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_STATE_ABR  \
# 0       2019        1              10994    CHS               SC
# 1       2019        1              10994    CHS               SC
# 2       2019        1              10994    CHS               SC
# 3       2019        1              10994    CHS               SC
# 4       2019        1              10994    CHS               SC
# ...      ...      ...                ...    ...              ...
# 454653  2021        4              14747    SEA               WA
# 454654  2021        4              14747    SEA               WA
# 454655  2021        4              14747    SEA               WA
# 454656  2021        4              14747    SEA               WA
# 454657  2021        4              14747    SEA               WA
#
#        ORIGIN_STATE_NM  DEST_AIRPORT_ID DEST DEST_STATE_ABR DEST_STATE_NM  \
# 0       South Carolina            13830  OGG             HI        Hawaii
# 1       South Carolina            12758  KOA             HI        Hawaii
# 2       South Carolina            12982  LIH             HI        Hawaii
# 3       South Carolina            12173  HNL             HI        Hawaii
# 4       South Carolina            12173  HNL             HI        Hawaii
# ...                ...              ...  ...            ...           ...
# 454653      Washington            13830  OGG             HI        Hawaii
# 454654      Washington            13830  OGG             HI        Hawaii
# 454655      Washington            13830  OGG             HI        Hawaii
# 454656      Washington            12173  HNL             HI        Hawaii
# 454657      Washington            12173  HNL             HI        Hawaii
#
#           AIRPORT_GROUP TK_CARRIER_GROUP OP_CARRIER_GROUP TICKET_CARRIER  \
# 0       CHS:EWR:SFO:OGG         UA:UA:UA         UA:UA:UA             UA
# 1       CHS:IAD:LAX:KOA         UA:UA:UA         UA:UA:UA             UA
# 2       CHS:IAD:LAX:LIH         UA:UA:UA         UA:UA:UA             UA
# 3       CHS:IAD:SFO:HNL         UA:UA:UA         C5:UA:UA             UA
# 4       CHS:IAH:SFO:HNL         UA:UA:UA         UA:UA:UA             UA
# ...                 ...              ...              ...            ...
# 454653      SEA:SJC:OGG            AS:AS            AS:AS             AS
# 454654      SEA:SJC:OGG            AS:AS            AS:AS             AS
# 454655      SEA:SJC:OGG            AS:AS            AS:AS             AS
# 454656          SEA:HNL               AS               AS             AS
# 454657      SEA:SMF:HNL            AS:HA            AS:HA             99
#
#        OPERATING_CARRIER  PASSENGERS  MARKET_FARE
# 0                     UA           1       355.00
# 1                     UA           1       444.00
# 2                     UA           1       467.00
# 3                     99           1       515.00
# 4                     UA           1       525.12
# ...                  ...         ...          ...
# 454653                AS           1       462.13
# 454654                AS           1       549.51
# 454655                AS           1       558.09
# 454656                AS           1       222.48
# 454657                99           1       445.00
#
# [1046220 rows x 17 columns]

# %%
clean_data_df= hawaii_flights.rename(columns=
                                
                                         {"YEAR": "Year",
                                         "QUARTER":"Quarter",
                                         "ORIGIN":"Origin",
                                         "ORIGIN_STATE_ABR":"State departure",
                                         "DEST":"Destination Airport",
                                         "DEST_STATE_ABR":"Destination State",
                                         "AIRPORT_GROUP":"Airport Group",
                                         "TICKET_CARRIER":"Ticket Carrier",
                                         "PASSENGERS":"Total Passengers",
                                         "MARKET_FARE":"Ticket Cost"
                                        }
                                    )

clean_data_df
# Out:
#         Year  Quarter  ORIGIN_AIRPORT_ID Origin State departure  \
# 0       2019        1              10994    CHS              SC
# 1       2019        1              10994    CHS              SC
# 2       2019        1              10994    CHS              SC
# 3       2019        1              10994    CHS              SC
# 4       2019        1              10994    CHS              SC
# ...      ...      ...                ...    ...             ...
# 454653  2021        4              14747    SEA              WA
# 454654  2021        4              14747    SEA              WA
# 454655  2021        4              14747    SEA              WA
# 454656  2021        4              14747    SEA              WA
# 454657  2021        4              14747    SEA              WA
#
#        ORIGIN_STATE_NM  DEST_AIRPORT_ID Destination Airport Destination State  \
# 0       South Carolina            13830                 OGG                HI
# 1       South Carolina            12758                 KOA                HI
# 2       South Carolina            12982                 LIH                HI
# 3       South Carolina            12173                 HNL                HI
# 4       South Carolina            12173                 HNL                HI
# ...                ...              ...                 ...               ...
# 454653      Washington            13830                 OGG                HI
# 454654      Washington            13830                 OGG                HI
# 454655      Washington            13830                 OGG                HI
# 454656      Washington            12173                 HNL                HI
# 454657      Washington            12173                 HNL                HI
#
#        DEST_STATE_NM    Airport Group TK_CARRIER_GROUP OP_CARRIER_GROUP  \
# 0             Hawaii  CHS:EWR:SFO:OGG         UA:UA:UA         UA:UA:UA
# 1             Hawaii  CHS:IAD:LAX:KOA         UA:UA:UA         UA:UA:UA
# 2             Hawaii  CHS:IAD:LAX:LIH         UA:UA:UA         UA:UA:UA
# 3             Hawaii  CHS:IAD:SFO:HNL         UA:UA:UA         C5:UA:UA
# 4             Hawaii  CHS:IAH:SFO:HNL         UA:UA:UA         UA:UA:UA
# ...              ...              ...              ...              ...
# 454653        Hawaii      SEA:SJC:OGG            AS:AS            AS:AS
# 454654        Hawaii      SEA:SJC:OGG            AS:AS            AS:AS
# 454655        Hawaii      SEA:SJC:OGG            AS:AS            AS:AS
# 454656        Hawaii          SEA:HNL               AS               AS
# 454657        Hawaii      SEA:SMF:HNL            AS:HA            AS:HA
#
#        Ticket Carrier OPERATING_CARRIER  Total Passengers  Ticket Cost
# 0                  UA                UA                 1       355.00
# 1                  UA                UA                 1       444.00
# 2                  UA                UA                 1       467.00
# 3                  UA                99                 1       515.00
# 4                  UA                UA                 1       525.12
# ...               ...               ...               ...          ...
# 454653             AS                AS                 1       462.13
# 454654             AS                AS                 1       549.51
# 454655             AS                AS                 1       558.09
# 454656             AS                AS                 1       222.48
# 454657             99                99                 1       445.00
#
# [1046220 rows x 17 columns]

# %%
airports_data_df = clean_data_df[['Year', 'Quarter','Origin','State departure','Destination Airport','Airport Group',
                                       'Ticket Carrier','Total Passengers','Ticket Cost']]
airports_data_df.head(100)
# Out:
#      Year  Quarter Origin State departure Destination Airport  \
# 0    2019        1    CHS              SC                 OGG
# 1    2019        1    CHS              SC                 KOA
# 2    2019        1    CHS              SC                 LIH
# 3    2019        1    CHS              SC                 HNL
# 4    2019        1    CHS              SC                 HNL
# ..    ...      ...    ...             ...                 ...
# 169  2019        1    SNA              CA                 HNL
# 171  2019        1    SNA              CA                 KOA
# 172  2019        1    SNA              CA                 MKK
# 174  2019        1    SNA              CA                 HNL
# 176  2019        1    SNA              CA                 KOA
#
#            Airport Group Ticket Carrier  Total Passengers  Ticket Cost
# 0        CHS:EWR:SFO:OGG             UA                 1       355.00
# 1        CHS:IAD:LAX:KOA             UA                 1       444.00
# 2        CHS:IAD:LAX:LIH             UA                 1       467.00
# 3        CHS:IAD:SFO:HNL             UA                 1       515.00
# 4        CHS:IAH:SFO:HNL             UA                 1       525.12
# ..                   ...            ...               ...          ...
# 169          SNA:PHX:HNL             AA                 1       252.00
# 171          SNA:PHX:KOA             AA                 1       254.00
# 172  SNA:PHX:KOA:HNL:MKK             99                 1       480.96
# 174      SNA:PHX:KOA:HNL             AA                 1       282.96
# 176          SNA:PHX:KOA             AA                 1       306.50
#
# [100 rows x 9 columns]
